# %%
import os
import glob
import sync

# %%
path_base  = 'D:/VoiceFilter/chime4_MLDR/'
path_clean = path_base + 'clean/' 
path_mldr  = path_base + 'mldr/'

# %%
for x in files_clean:
    print(x)
    y = x.split('\\');
    print(y)
    z = y[-1]
    print(z)
    break
# Out:
# D:/VoiceFilter/chime4_MLDR/clean\dt05_bth_0\F01_050C0103_BTH.CH0.wav
# ['D:/VoiceFilter/chime4_MLDR/clean', 'dt05_bth_0', 'F01_050C0103_BTH.CH0.wav']
# F01_050C0103_BTH.CH0.wav

# %%
import sync
files_mldr = sync.get_wave_list_recursive(path_mldr)
print(files_mldr)

files_clean = sync.get_wave_list_recursive(path_clean)
print(files_clean)
# Out:
# ['D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C0103_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C0105_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C010C_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C010G_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C010J_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C010K_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C010L_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C010O_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C010P_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C010R_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C010U_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C010W_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C0112_BUS.wav', 'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C0116
# ...

# %% [markdown]
# A_B_BTH.CH0.wav
# A_B_BUS.wav
#
# 이런식으로 구분이 되어있고. 저 A,B가 공통이므로 저 둘을 기준으로 묶어야한다.
# 결국엔 pandas로 가야하나? ls

# %%
import pandas as pd

# %%
x = 'F01_050C0103'
a = ['D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C0103_BUS.wav','D:/VoiceFilter/chime4_MLDR/mldr\\dt05_caf_simu\\F01_050C0103_CAF.wav']
b = 'D:/VoiceFilter/chime4_MLDR/clean\\dt05_bth_0\\F01_050C0103_BTH.CH0.wav'

# %%
df = pd.DataFrame(columns={'clean','mldr'})
df.loc[x] = {'clean':b, 'mldr':a}
df.loc[x]['mldr']
# Out:
# ['D:/VoiceFilter/chime4_MLDR/mldr\\dt05_bus_simu\\F01_050C0103_BUS.wav',
#  'D:/VoiceFilter/chime4_MLDR/mldr\\dt05_caf_simu\\F01_050C0103_CAF.wav']

# %% [markdown]
# 이제 이걸 전체 파일 리스트에서 대해서 돌리면 된다.

# %%
import pydub
# Out:
# C:\Users\구본혁\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
