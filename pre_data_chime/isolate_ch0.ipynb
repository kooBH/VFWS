# %%
import os
import glob
import shutil

# %%
path = 'D:/VoiceFilter/chime4_MLDR/clean/'

# %%
target = [ x for x in glob.glob(path +'et05_bth/*.CH0.wav')]

# %%
print(target)
# Out:
# ['D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_440C0202_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_440C0204_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_440C0209_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_440C020E_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_440C020F_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_440C020G_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_440C020H_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_440C020I_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_440C020O_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_440C020P_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_440C020T_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_440C0210_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_441C0207_BTH.CH0.wav', 'D:/VoiceFilter/chime4_MLDR/clean/et05_bth\\F05_441C020T_BTH.CH0.wav', 'D:
# ...

# %%
for x in target :
    print(x)
# Out:
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_440C0202_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_440C0204_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_440C0209_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_440C020E_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_440C020F_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_440C020G_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_440C020H_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_440C020I_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_440C020O_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_440C020P_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_440C020T_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_440C0210_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_441C0207_BTH.CH0.wav
# D:/VoiceFilter/chime4_MLDR/clean/et05_bth\F05_441C020T_BTH.CH0.wav
# ...

# %%
for x in target :
    shutil.move(x, path+'et05_bth_0')
